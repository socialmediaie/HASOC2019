# %% [markdown]
# <a href="https://colab.research.google.com/github/napsternxg/HASOC2019/blob/master/notebooks/HASOC_experiment_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions for running notebook
#
# * First download the latest code from the repo
# * Upload the code to your google drive which will be used for running colab
# * Run this notebook and use the same google account for authentication which has the folder

# %%
# %%bash
# pip install torch pytorch-transformers tensorboardX tf-nightly-2.0-preview
# # Install apex
# if [ ! -d "/content/apex" ]; then
#   git clone https://github.com/NVIDIA/apex.git
#   pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" /content/apex
# else
#   echo "Apex cloned and installed";
# fi
# Out:
# ...
#   Created wheel for regex: filename=regex-2019.8.19-cp36-cp36m-linux_x86_64.whl size=609246 sha256=7d0cc5da23b4f42644162390259bfe33e25e7d636728802aa3144989efba5195
#   Stored in directory: /root/.cache/pip/wheels/90/04/07/b5010fb816721eb3d6dd64ed5cc8111ca23f97fdab8619b5be
# ...
#   Created wheel for opt-einsum: filename=opt_einsum-3.0.1-cp36-none-any.whl size=58500 sha256=fbb8c95cdb8e8cccb325b71bc6649c4d56e2642fa989afe9c05c809898d69f24
#   Stored in directory: /root/.cache/pip/wheels/91/98/8d/10e3d4e04c959597a411b91acd3695e9e2d210e68ce3427aad
# Successfully built regex opt-einsum
# ...
# Created temporary directory: /tmp/pip-ephem-wheel-cache-memshm_6
# Created temporary directory: /tmp/pip-req-tracker-owoe5a_6
# Created requirements tracker '/tmp/pip-req-tracker-owoe5a_6'
# Created temporary directory: /tmp/pip-install-exl2kzf3
# Processing ./apex
#   Created temporary directory: /tmp/pip-req-build-ief9nqhq
#   Added file:///content/apex to build tracker '/tmp/pip-req-tracker-owoe5a_6'
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %env HASOC_PATH /content/gdrive/My Drive/HASOC2019/
# Out:
# env: HASOC_PATH=/content/gdrive/My Drive/HASOC2019/

# %%
# %%bash
# python "${HASOC_PATH}"/src/generate_data.py --help
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# usage: generate_data.py [-h] [--seed SEED]
#
# optional arguments:
#   -h, --help   show this help message and exit
#   --seed SEED  random seed for initialization

# %%
# %%bash
# python "${HASOC_PATH}"/src/generate_data.py
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# train
# ./EN/task_1/train.tsv
# ./EN/task_2/train.tsv
# ./EN/task_3/train.tsv
# ./EN/task_4/train.tsv
# ./DE/task_1/train.tsv
# ./DE/task_2/train.tsv
# ./DE/task_4/train.tsv
# ./HI/task_1/train.tsv
# ./HI/task_2/train.tsv
# ./HI/task_3/train.tsv
# ./HI/task_4/train.tsv
# dev
# ./EN/task_1/dev.tsv
# ./EN/task_2/dev.tsv
# ./EN/task_3/dev.tsv
# ./EN/task_4/dev.tsv
# ./DE/task_1/dev.tsv
# ./DE/task_2/dev.tsv
# ./DE/task_4/dev.tsv
# ./HI/task_1/dev.tsv
# ./HI/task_2/dev.tsv
# ./HI/task_3/dev.tsv
# ./HI/task_4/dev.tsv
# test
# ./EN/task_1/test.tsv
# ./EN/task_2/test.tsv
# ./EN/task_3/test.tsv
# ./EN/task_4/test.tsv
# ./DE/task_1/test.tsv
# ./DE/task_2/test.tsv
# ./DE/task_4/test.tsv
# ./HI/task_1/test.tsv
# ./HI/task_2/test.tsv
# ...

# %%
# %%bash
# python "${HASOC_PATH}"/src/run_experiment.py --help
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# usage: run_experiment.py [-h] --data_dir DATA_DIR --bert_model_type
#                          BERT_MODEL_TYPE --task TASK --lang LANG --output_dir
#                          OUTPUT_DIR [--cache_dir CACHE_DIR]
#                          [--max_seq_length MAX_SEQ_LENGTH] [--do_train]
#                          [--do_eval] [--evaluate_during_training]
#                          [--do_lower_case]
#                          [--train_batch_size TRAIN_BATCH_SIZE]
#                          [--eval_batch_size EVAL_BATCH_SIZE]
#                          [--gradient_accumulation_steps GRADIENT_ACCUMULATION_STEPS]
#                          [--learning_rate LEARNING_RATE]
#                          [--weight_decay WEIGHT_DECAY]
# ...

# %%
# %%bash
# TASK="task_1"
# LANG="EN"
# MODEL="bert-base-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./EN/task_1/output/model
# (1153, 2) (1153,)
# test: {'eval_loss': 1.2017842668133814, 'NOT/precision': 1.0, 'NOT/recall': 0.6461405030355594, 'NOT/f1-score': 0.7850368809272918, 'NOT/support': 1153, 'HOF/precision': 0.0, 'HOF/recall': 0.0, 'HOF/f1-score': 0.0, 'HOF/support': 0, 'accuracy': 0.6461405030355594, 'macro avg/precision': 0.5, 'macro avg/recall': 0.3230702515177797, 'macro avg/f1-score': 0.3925184404636459, 'macro avg/support': 1153, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.6461405030355594, 'weighted avg/f1-score': 0.7850368809272918, 'weighted avg/support': 1153}
# (505, 2) (505,)
# ...

# %%
# %%bash
# TASK="task_2"
# LANG="EN"
# MODEL="bert-base-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./EN/task_2/output/model
# (1153, 3) (1153,)
# test: {'eval_loss': 0.5549445750342833, 'HATE/precision': 1.0, 'HATE/recall': 0.797918473547268, 'HATE/f1-score': 0.8876025084418717, 'HATE/support': 1153, 'OFFN/precision': 0.0, 'OFFN/recall': 0.0, 'OFFN/f1-score': 0.0, 'OFFN/support': 0, 'PRFN/precision': 0.0, 'PRFN/recall': 0.0, 'PRFN/f1-score': 0.0, 'PRFN/support': 0, 'accuracy': 0.797918473547268, 'macro avg/precision': 0.3333333333333333, 'macro avg/recall': 0.265972824515756, 'macro avg/f1-score': 0.29586750281395724, 'macro avg/support': 1153, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.797918473547268, 'weighted avg/f1-score': 0.8876025084418717, 'weighted avg/support': 1153}
# ...

# %%
# %%bash
# TASK="task_3"
# LANG="EN"
# MODEL="bert-base-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./EN/task_3/output/model
# (1153, 2) (1153,)
# test: {'eval_loss': 0.41140548482134537, 'TIN/precision': 1.0, 'TIN/recall': 0.805724197745013, 'TIN/f1-score': 0.8924111431316043, 'TIN/support': 1153, 'UNT/precision': 0.0, 'UNT/recall': 0.0, 'UNT/f1-score': 0.0, 'UNT/support': 0, 'accuracy': 0.805724197745013, 'macro avg/precision': 0.5, 'macro avg/recall': 0.4028620988725065, 'macro avg/f1-score': 0.44620557156580215, 'macro avg/support': 1153, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.805724197745013, 'weighted avg/f1-score': 0.8924111431316043, 'weighted avg/support': 1153}
# (299, 2) (299,)
# ...

# %%
# %%bash
# TASK="task_4"
# LANG="EN"
# MODEL="bert-base-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./EN/task_4/output/model
# (1153, 7) (1153,)
# ...

# %% [markdown]
# ## English uncased

# %%
# %%bash
# TASK="task_1"
# LANG="EN"
# MODEL="bert-base-uncased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-uncased" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./EN/task_1/output-uncased/model
# (1153, 2) (1153,)
# test: {'eval_loss': 1.2199110968692883, 'NOT/precision': 1.0, 'NOT/recall': 0.6366001734605378, 'NOT/f1-score': 0.7779544250132485, 'NOT/support': 1153, 'HOF/precision': 0.0, 'HOF/recall': 0.0, 'HOF/f1-score': 0.0, 'HOF/support': 0, 'accuracy': 0.6366001734605378, 'macro avg/precision': 0.5, 'macro avg/recall': 0.3183000867302689, 'macro avg/f1-score': 0.38897721250662426, 'macro avg/support': 1153, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.6366001734605378, 'weighted avg/f1-score': 0.7779544250132485, 'weighted avg/support': 1153}
# (505, 2) (505,)
# ...

# %%
# %%bash
# TASK="task_2"
# LANG="EN"
# MODEL="bert-base-uncased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-uncased" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./EN/task_2/output-uncased/model
# (1153, 3) (1153,)
# test: {'eval_loss': 0.5293082531440902, 'HATE/precision': 1.0, 'HATE/recall': 0.797918473547268, 'HATE/f1-score': 0.8876025084418717, 'HATE/support': 1153, 'OFFN/precision': 0.0, 'OFFN/recall': 0.0, 'OFFN/f1-score': 0.0, 'OFFN/support': 0, 'PRFN/precision': 0.0, 'PRFN/recall': 0.0, 'PRFN/f1-score': 0.0, 'PRFN/support': 0, 'accuracy': 0.797918473547268, 'macro avg/precision': 0.3333333333333333, 'macro avg/recall': 0.265972824515756, 'macro avg/f1-score': 0.29586750281395724, 'macro avg/support': 1153, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.797918473547268, 'weighted avg/f1-score': 0.8876025084418717, 'weighted avg/support': 1153}
# ...

# %%
# %%bash
# TASK="task_3"
# LANG="EN"
# MODEL="bert-base-uncased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-uncased" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./EN/task_3/output-uncased/model
# (1153, 2) (1153,)
# test: {'eval_loss': 0.4870299757332415, 'TIN/precision': 1.0, 'TIN/recall': 0.7736339982653946, 'TIN/f1-score': 0.8723716381418093, 'TIN/support': 1153, 'UNT/precision': 0.0, 'UNT/recall': 0.0, 'UNT/f1-score': 0.0, 'UNT/support': 0, 'accuracy': 0.7736339982653946, 'macro avg/precision': 0.5, 'macro avg/recall': 0.3868169991326973, 'macro avg/f1-score': 0.43618581907090465, 'macro avg/support': 1153, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.7736339982653946, 'weighted avg/f1-score': 0.8723716381418093, 'weighted avg/support': 1153}
# (297, 2) (297,)
# ...

# %%
# %%bash
# TASK="task_4"
# LANG="EN"
# MODEL="bert-base-uncased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-uncased" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./EN/task_4/output-uncased/model
# (1153, 7) (1153,)
# ...

# %%
# %%bash
# LANG="EN"
# MODEL="bert-base-uncased"
# base_dir="${HASOC_PATH}/outputs/${LANG}/${MODEL}/"
# mkdir -p "${base_dir}"
# for task in ( "task_1" "task_2" "task_3" "task_4" ); do
#   mkdir -p "${base_dir}/${task}"
#   cp "${LANG}/${task}/output-uncased/"*.tsv "${base_dir}/${task}/"
#   cp "${LANG}/${task}/output-uncased/events.out"* "${base_dir}/${task}/"
#   cp "${LANG}/${task}/output-uncased/"*.json "${base_dir}/${task}/"
# done
# Out:
# bash: line 5: syntax error near unexpected token `('
# bash: line 5: `for task in ( "task_1" "task_2" "task_3" "task_4" ); do'

# %% [markdown]
# # GERMAN

# %%
# %%bash
# TASK="task_1"
# LANG="DE"
# MODEL="bert-base-multilingual-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \

# %%
# %%bash
# TASK="task_2"
# LANG="DE"
# MODEL="bert-base-multilingual-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \

# %%
# %%bash
# TASK="task_4"
# LANG="DE"
# MODEL="bert-base-multilingual-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./DE/task_4/output/model
# (850, 7) (850,)
# ...

# %% [markdown]
# # German-cased

# %%
# %%bash
# TASK="task_1"
# LANG="DE"
# MODEL="bert-base-german-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-german" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./DE/task_1/output-german/model
# (850, 2) (850,)
# test: {'eval_loss': 0.19439996275360938, 'NOT/precision': 1.0, 'NOT/recall': 0.9482352941176471, 'NOT/f1-score': 0.9734299516908212, 'NOT/support': 850, 'HOF/precision': 0.0, 'HOF/recall': 0.0, 'HOF/f1-score': 0.0, 'HOF/support': 0, 'accuracy': 0.9482352941176471, 'macro avg/precision': 0.5, 'macro avg/recall': 0.47411764705882353, 'macro avg/f1-score': 0.4867149758454106, 'macro avg/support': 850, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.9482352941176471, 'weighted avg/f1-score': 0.9734299516908212, 'weighted avg/support': 850}
# (794, 2) (794,)
# ...

# %%
# %%bash
# TASK="task_2"
# LANG="DE"
# MODEL="bert-base-german-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-german" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./DE/task_2/output-german/model
# (850, 3) (850,)
# test: {'eval_loss': 1.6206253457952429, 'HATE/precision': 1.0, 'HATE/recall': 0.10941176470588235, 'HATE/f1-score': 0.1972428419936373, 'HATE/support': 850, 'OFFN/precision': 0.0, 'OFFN/recall': 0.0, 'OFFN/f1-score': 0.0, 'OFFN/support': 0, 'PRFN/precision': 0.0, 'PRFN/recall': 0.0, 'PRFN/f1-score': 0.0, 'PRFN/support': 0, 'accuracy': 0.10941176470588235, 'macro avg/precision': 0.3333333333333333, 'macro avg/recall': 0.036470588235294116, 'macro avg/f1-score': 0.06574761399787911, 'macro avg/support': 850, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.10941176470588235, 'weighted avg/f1-score': 0.1972428419936373, 'weighted avg/support': 850}
# ...

# %%
# %%bash
# TASK="task_4"
# LANG="DE"
# MODEL="bert-base-german-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-german" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./DE/task_4/output-german/model
# (850, 7) (850,)
# ...

# %% [markdown]
# # Hindi

# %%
# %%bash
# TASK="task_1"
# LANG="HI"
# MODEL="bert-base-multilingual-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \

# %%
# %%bash
# TASK="task_2"
# LANG="HI"
# MODEL="bert-base-multilingual-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./HI/task_2/output/model
# (1318, 3) (1318,)
# test: {'eval_loss': 1.4285018302145458, 'HATE/precision': 1.0, 'HATE/recall': 0.5933232169954477, 'HATE/f1-score': 0.7447619047619047, 'HATE/support': 1318, 'OFFN/precision': 0.0, 'OFFN/recall': 0.0, 'OFFN/f1-score': 0.0, 'OFFN/support': 0, 'PRFN/precision': 0.0, 'PRFN/recall': 0.0, 'PRFN/f1-score': 0.0, 'PRFN/support': 0, 'accuracy': 0.5933232169954477, 'macro avg/precision': 0.3333333333333333, 'macro avg/recall': 0.19777440566514923, 'macro avg/f1-score': 0.24825396825396825, 'macro avg/support': 1318, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.5933232169954477, 'weighted avg/f1-score': 0.7447619047619047, 'weighted avg/support': 1318}
# ...

# %%
# %%bash
# TASK="task_3"
# LANG="HI"
# MODEL="bert-base-multilingual-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./HI/task_3/output/model
# (1318, 2) (1318,)
# test: {'eval_loss': 0.3602239645662762, 'TIN/precision': 1.0, 'TIN/recall': 0.9673748103186647, 'TIN/f1-score': 0.9834168916313152, 'TIN/support': 1318, 'UNT/precision': 0.0, 'UNT/recall': 0.0, 'UNT/f1-score': 0.0, 'UNT/support': 0, 'accuracy': 0.9673748103186647, 'macro avg/precision': 0.5, 'macro avg/recall': 0.48368740515933234, 'macro avg/f1-score': 0.4917084458156576, 'macro avg/support': 1318, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.9673748103186647, 'weighted avg/f1-score': 0.9834168916313152, 'weighted avg/support': 1318}
# (72, 2) (72,)
# ...

# %%
# %%bash
# TASK="task_4"
# LANG="HI"
# MODEL="bert-base-multilingual-cased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# Process is terminated.

# %% [markdown]
# # Hindi uncased models

# %%
# %%bash
# TASK="task_1"
# LANG="HI"
# MODEL="bert-base-multilingual-uncased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-uncased" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \

# %%
# %%bash
# TASK="task_2"
# LANG="HI"
# MODEL="bert-base-multilingual-uncased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-uncased" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./HI/task_2/output-uncased/model
# (1318, 3) (1318,)
# test: {'eval_loss': 1.5942152426356362, 'HATE/precision': 1.0, 'HATE/recall': 0.5925644916540213, 'HATE/f1-score': 0.7441638875655073, 'HATE/support': 1318, 'OFFN/precision': 0.0, 'OFFN/recall': 0.0, 'OFFN/f1-score': 0.0, 'OFFN/support': 0, 'PRFN/precision': 0.0, 'PRFN/recall': 0.0, 'PRFN/f1-score': 0.0, 'PRFN/support': 0, 'accuracy': 0.5925644916540213, 'macro avg/precision': 0.3333333333333333, 'macro avg/recall': 0.19752149721800707, 'macro avg/f1-score': 0.24805462918850243, 'macro avg/support': 1318, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.5925644916540213, 'weighted avg/f1-score': 0.7441638875655073, 'weighted avg/support': 1318}
# ...

# %%
# %%bash
# TASK="task_3"
# LANG="HI"
# MODEL="bert-base-multilingual-uncased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-uncased" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./HI/task_3/output-uncased/model
# (1318, 2) (1318,)
# test: {'eval_loss': 0.6050219269735473, 'TIN/precision': 1.0, 'TIN/recall': 0.7731411229135053, 'TIN/f1-score': 0.8720581942661532, 'TIN/support': 1318, 'UNT/precision': 0.0, 'UNT/recall': 0.0, 'UNT/f1-score': 0.0, 'UNT/support': 0, 'accuracy': 0.7731411229135053, 'macro avg/precision': 0.5, 'macro avg/recall': 0.38657056145675267, 'macro avg/f1-score': 0.4360290971330766, 'macro avg/support': 1318, 'weighted avg/precision': 1.0, 'weighted avg/recall': 0.7731411229135053, 'weighted avg/f1-score': 0.8720581942661532, 'weighted avg/support': 1318}
# (72, 2) (72,)
# ...

# %%
# %%bash
# TASK="task_4"
# LANG="HI"
# MODEL="bert-base-multilingual-uncased"
# python "${HASOC_PATH}"/src/run_experiment.py \
# --data_dir "./${LANG}/${TASK}" \
# --bert_model_type "${MODEL}" \
# --task ${TASK} \
# --lang ${LANG} \
# --output_dir "./${LANG}/${TASK}/output-uncased" \
# --cache_dir "./${LANG}/${TASK}" \
# --num_train_epochs 5 \
# --train_batch_size 32 \
# --eval_batch_size 32 \
# --save_steps 50 \
# --logging_steps 5 \
# --gradient_accumulation_steps 2 \
# Out:
# {'EN': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/english_dataset.tsv', 'DE': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/german_dataset.tsv', 'HI': '/content/gdrive/My Drive/HASOC2019//data/raw/training_data/hindi_dataset.tsv'}
# saving model in ./HI/task_4/output-uncased/model
# (1318, 7) (1318,)
# ...
